# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
data = pd.read_csv("homeprice.csv")
X = data[['area']].values
y = data['price'].values
X_b = np.c_[np.ones((X.shape[0], 1)), X]
theta = np.linalg.inv(X_b.T.dot(X_b)).dot(X_b.T).dot(y)
y_pred = X_b.dot(theta)

# %%
mae = np.mean(np.abs(y - y_pred))
mse = np.mean((y - y_pred) ** 2)
rmse = np.sqrt(mse)
r_squared = 1 - (np.sum((y - y_pred) ** 2) / np.sum((y - np.mean(y)) ** 2))

# %%
plt.scatter(X, y, color='red', label='Actual data')
plt.plot(X, y_pred, color='orange', label='Linear regression')
plt.xlabel('X')
plt.ylabel('y')
plt.legend()
plt.show()

# %%
print(f"Coefficients: {theta}")
print(f"Mean Absolute Error (MAE): {mae}")
print(f"Mean Squared Error (MSE): {mse}")
print(f"Root Mean Squared Error (RMSE): {rmse}")
print(f"R-squared: {r_squared}")
# Out:
# Coefficients: [1.80616438e+05 1.35787671e+02]
# Mean Absolute Error (MAE): 11246.575342465378
# Mean Squared Error (MSE): 186815068.49315077
# Root Mean Squared Error (RMSE): 13668.03089304201
# R-squared: 0.9584301138199487
